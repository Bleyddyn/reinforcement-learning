# %%
# %matplotlib inline

import sys
sys.path.insert(0,'/Users/andrew/Library/Python/2.7/lib/python/site-packages/')
import numpy as np

import gym
from matplotlib import pyplot as plt
# Out:
# WARNING:gym:You have 'numpy' version 1.9.1 installed, but 'gym' requires at least 1.10.4. HINT: upgrade via 'pip install -U numpy'.
# [2017-04-02 13:06:30,780] You have 'numpy' version 1.9.1 installed, but 'gym' requires at least 1.10.4. HINT: upgrade via 'pip install -U numpy'.

# %%
env = gym.envs.make("MountainCar-v0")
# Out:
# INFO:gym.envs.registration:Making new env: MountainCar-v0
# [2017-04-02 13:06:32,096] Making new env: MountainCar-v0

# %%
print env.action_space
print env.observation_space

env.reset()
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(0) for x in range(100)]
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(1) for x in range(100)]
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(2) for x in range(100)]
plt.figure()
plt.imshow(env.render(mode='rgb_array'))


env.render(close=True)
# Out:
# Discrete(3)
# Box(2,)

# %%
state = env.reset()

for _ in range(100):
    print state
    state, reward, done, info = env.step(0)
# Out:
# [-0.58045305  0.        ]
# [ -5.81028707e-01  -5.75657422e-04]
# [-0.58217577 -0.00114706]
# [-0.58388576 -0.00170999]
# [-0.58614606 -0.0022603 ]
# [-0.58894    -0.00279394]
# [-0.59224702 -0.00330702]
# [-0.5960428  -0.00379579]
# [-0.60029953 -0.00425672]
# [-0.60498606 -0.00468653]
# [-0.61006823 -0.00508217]
# [-0.61550913 -0.0054409 ]
# [-0.6212694  -0.00576027]
# [-0.62730759 -0.00603818]
# [-0.63358044 -0.00627285]
# [-0.64004332 -0.00646288]
# [-0.64665051 -0.0066072 ]
# [-0.65335564 -0.00670513]
# [-0.66011199 -0.00675634]
# [-0.66687286 -0.00676088]
# [-0.67359196 -0.0067191 ]
# [-0.6802237  -0.00663174]
# [-0.6867235 -0.0064998]
# [-0.69304811 -0.00632461]
# [-0.69915589 -0.00610778]
# [-0.70500702 -0.00585113]
# [-0.71056376 -0.00555674]
# [-0.71579065 -0.00522688]
# [-0.72065464 -0.00486399]
# [-0.7251253  -0.00447066]
# [-0.72917493 -0.00404962]
# [-0.73277863 -0.0036037 ]
